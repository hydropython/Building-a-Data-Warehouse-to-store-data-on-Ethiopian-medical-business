# %%
! pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.13 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.5/112.6 GB disk)

# %%
from ultralytics import YOLO
import os
from IPython.display import display,Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics 8.3.13 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/112.6 GB disk)
#
# OS                  Linux-6.1.85+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.67 GB
# Disk                28.9/112.6 GB
# CPU                 Intel Xeon 2.30GHz
# CPU count           2
# GPU                 Tesla T4, 15102MiB
# GPU count           1
# CUDA                12.1
#
# numpy               ✅ 1.26.4>=1.23.0
# matplotlib          ✅ 3.7.1>=3.3.0
# opencv-python       ✅ 4.10.0.84>=4.6.0
# pillow              ✅ 10.4.0>=7.1.2
# pyyaml              ✅ 6.0.2>=5.3.1
# requests            ✅ 2.32.3>=2.23.0
# scipy               ✅ 1.13.1>=1.4.1
# torch               ✅ 2.4.1+cu121>=1.8.0
# torchvision         ✅ 0.19.1+cu121>=0.9.0
# tqdm                ✅ 4.66.5>=4.64.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="sWnk2IOLzhecokdw6otz")
project = rf.workspace("robo-irnwv").project("datawarehouse_medical")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.3.13, to fix: `pip install ultralytics==8.0.196`

# %%
# !yolo task=detect mode=train model=yolov8m.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.13 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train4/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.13 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 236 layers, 23,208,622 parameters, 0 gradients, 67.5 GFLOPs
# val: Scanning /content/datawarehouse_medical-1/valid/labels.cache... 49 images, 4 backgrounds, 0 corrupt: 100% 49/49 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:02<00:00,  1.48it/s]
#                    all         49         45       0.67      0.593      0.729      0.575
#              Cosmetics         17         17      0.914      0.623      0.884      0.626
#          Food packages          6          6      0.979      0.833      0.972      0.658
#               Medicine          1          1      0.727          1      0.995      0.895
#            Milk powder          5          5      0.653        0.8      0.796      0.723
# Pregenancy supplements          4          4          0          0      0.084     0.0433
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train4/weights/best.pt data={dataset.location}/data.yaml
# Out:
# WARNING ⚠️ 'source' argument is missing. Using default 'source=/usr/local/lib/python3.10/dist-packages/ultralytics/assets'.
# Ultralytics 8.3.13 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 236 layers, 23,208,622 parameters, 0 gradients, 67.5 GFLOPs
#
# image 1/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/bus.jpg: 640x480 1 Medicine, 62.3ms
# image 2/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/zidane.jpg: 384x640 1 Medicine, 42.3ms
# Speed: 2.4ms preprocess, 52.3ms inference, 323.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
